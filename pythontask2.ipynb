# %%
def calculator():
    print("Basic Calculator")
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))
    operator = input("Enter operator (+, -, *, /,**): ")

    if operator == '+':
        print("   Addition   ")
        print("Result:", num1 + num2)
    elif operator == '-':
        print("   Subtraction   ")
        print("Result:", num1 - num2)
    elif operator == '*':
        print("   Multiplication   ")
        print("Result:", num1 * num2)
    elif operator == '**':
        print("   Exponentiation   ")
        print("Result:", num1 ** num2)
    elif operator == '/':
        print ("   Division   ")
        if num2 != 0:
            print("Result:", num1 / num2)
        else:
            print("Cannot divide by zero.")
    else:
        print("Invalid operator.Please enter a correct operator.")

calculator()
# Out:
# Basic Calculator
# Enter first number: 4
# Enter second number: 4
# Enter operator (+, -, *, /,**): **
#    Exponentiation
# Result: 256.0
